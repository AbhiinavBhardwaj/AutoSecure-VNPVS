# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\vashi\Desktop\minor project\data\vehicle_database.csv")
print(df.columns)
# Out:
# Index(['NumberPlate', 'Color', 'Brand', 'OwnerName'], dtype='object')
